# %%
import pandas as pd
import plotnine as pln

import warnings
from plotnine.exceptions import PlotnineWarning

warnings.filterwarnings("ignore", category=PlotnineWarning)

# %%
iris_df = pd.read_csv(r'Iris.csv')
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='str')

# %%
iris_df['Species'].unique()
# Out:
# <StringArray>
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# Length: 3, dtype: str

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm', y = 'SepalWidthCm')) + pln.geom_point()

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm', y = 'SepalWidthCm', shape = 'Species')) + pln.geom_point()

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'Species')) + pln.geom_point()

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm', y = 'SepalWidthCm', shape = 'Species', color = 'Species')) + pln.geom_point()

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm', y = 'SepalWidthCm')) + pln.geom_point() + pln.facet_wrap('Species')

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalLengthCm')) + pln.geom_histogram()

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalWidthCm')) + pln.geom_histogram() + pln.facet_wrap('Species')

# %%
pln.ggplot(iris_df, pln.aes(x = 'SepalWidthCm')) + pln.geom_histogram() + pln.facet_wrap('Species', nrow=3)

# %%
setosa_df = iris_df.loc[iris_df['Species']=='Iris-setosa']

versicolor_df = iris_df.loc[iris_df['Species']=='Iris-versicolor']

virginica_df = iris_df.loc[iris_df['Species']=='Iris-virginica']

# %%
pln.ggplot() + \
pln.geom_histogram(setosa_df, pln.aes(x = 'SepalWidthCm'), binwidth = 0.1, fill = 'blue') + \
pln.geom_histogram(versicolor_df, pln.aes(x='SepalWidthCm'), binwidth = 0.1, fill = 'green') + \
pln.geom_histogram(virginica_df, pln.aes(x='SepalWidthCm'), binwidth = 0.1, fill = 'red')

# %% [markdown]
# Adding alpha = 0.5 controling the trasparency of the graph.

# %%
pln.ggplot() + \
    pln.geom_histogram(setosa_df, pln.aes(x = 'SepalWidthCm'), binwidth = 0.1, fill = 'blue', alpha = 0.5) + \
        pln.geom_histogram(versicolor_df, pln.aes(x='SepalWidthCm'), binwidth = 0.1, fill = 'green', alpha = 0.5) + \
            pln.geom_histogram(virginica_df, pln.aes(x='SepalWidthCm'), binwidth = 0.1, fill = 'red', alpha = 0.5)

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + pln.geom_boxplot()

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + pln.geom_boxplot() + pln.geom_jitter(width = 0.5)

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + pln.geom_boxplot() + pln.geom_jitter(width = 0.25)

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + pln.geom_boxplot() + pln.geom_jitter(width = 0)

# %% [markdown]
# Defining title name and colors

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + \
    pln.geom_boxplot() + \
        pln.geom_jitter(width = 0.5) + \
            pln.xlab('iris species') + \
                pln.ylab('sepal width (cm)') + \
                    pln.ggtitle('IRIS sepal width by species') + \
                        pln.scale_fill_manual(values = ['skyblue', 'royalblue', 'blue'])

# %% [markdown]
# Defining scope of Y axis with .ylim(min,max)

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + \
    pln.geom_boxplot() + \
        pln.geom_jitter(width = 0.5) + \
            pln.xlab('iris species') + \
                pln.ylab('sepal width (cm)') + \
                    pln.ggtitle('IRIS sepal width by species') + \
                        pln.scale_fill_manual(values = ['skyblue', 'royalblue', 'blue']) + \
                            pln.ylim(2, 5)

# %%
pln.ggplot(iris_df, pln.aes(x='Species', y='SepalWidthCm', fill='Species')) + \
    pln.geom_boxplot() + \
        pln.geom_jitter(width = 0.5) + \
            pln.xlab('iris species') + \
                pln.ylab('sepal width (cm)') + \
                    pln.ggtitle('IRIS sepal width by species') + \
                        pln.scale_fill_manual(values = ['skyblue', 'royalblue', 'blue']) + \
                            pln.scale_y_continuous(limits = [2, 5])
